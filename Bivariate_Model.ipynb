# %%
import os

# %%
os.chdir("D:\Courses\CE 7090 -Statistical and Econometric Methods in Civil Engineering II\HomeWork\HW-5")

# %%
df = pd.read_csv('homework_5_survey_data.csv')

# %%
df
# Out:
#      x1   x2   x3  x4   x5  x6  x7  x8  x9  x10  ...  x33  x34  x35  x36  x37  \
# 0     0    1    1   1    0   0   1   1   0 -999  ...    2    8    3    4    2
# 1     3    1    3   0 -999   0   1   1   1 -999  ...    2    5    2    2    2
# 2     0    1    3   0 -999   0   1   0   0 -999  ...    2    6    4    5    2
# 3     4 -999    0   0 -999   4   1   1   0 -999  ...    2    6    2    2    2
# 4     1    1    1   0 -999   1   1   0   0 -999  ...    1    6    3    2    2
# ..   ..  ...  ...  ..  ...  ..  ..  ..  ..  ...  ...  ...  ...  ...  ...  ...
# 245   0    0 -999   1    1   0   1   1   0 -999  ...    1    6    4    3    2
# 246   0    0 -999   0 -999   0   1   1   0 -999  ...    4    3    1    2    2
# 247   0    1    1   1    3   0   0   0   1 -999  ...    2    7    3    4    2
# 248   0    1    1   1    0   0   1   0   1 -999  ...    1    6    1    6    4
# 249   2    1    2   1    0   2   1   0   0 -999  ...    2    8    4    4    2
#
#      x38  x39    x40    x41  x42
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
# ...
